# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('gurgaon_properties.csv')

# %%
df.sample(5)
# Out:
#                                       property_name property_type  \
# 906   5 Bedroom House for sale in Sector 33 Gurgaon         house
# 3710                3 BHK Flat in Sector 92 Gurgaon          flat
# 2631                            2 BHK Flat in Sohna          flat
# 1742               3 BHK Flat in Sector 108 Gurgaon          flat
# 3543                2 BHK Flat in Sector 86 Gurgaon          flat
#
#                           society  price  price_per_sqft    area  \
# 906      unitech uniworld resorts    NaN             NaN     NaN
# 3710  bestech park view sanskruti   1.60          7547.0  2120.0
# 2631              eldeco accolade   0.71          4907.0  1447.0
# 1742                 raheja vedas   2.15          4134.0  5201.0
# 3543                pyramid elite   0.45          7846.0   574.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 906                         Plot area 520(434.79 sq.m.)        5         8
# ...

# %%
df.shape
# Out:
# (3961, 20)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3961 entries, 0 to 3960
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3961 non-null   object
#  1   property_type    3961 non-null   object
#  2   society          3960 non-null   object
#  3   price            3941 non-null   float64
#  4   price_per_sqft   3941 non-null   float64
#  5   area             3941 non-null   float64
#  6   areaWithType     3961 non-null   object
#  7   bedRoom          3961 non-null   int64
#  8   bathroom         3961 non-null   int64
#  9   balcony          3961 non-null   object
#  10  additionalRoom   3961 non-null   object
#  11  address          3950 non-null   object
#  12  floorNum         3940 non-null   float64
#  13  facing           2784 non-null   object
#  14  agePossession    3960 non-null   object
#  15  nearbyLocations  3754 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# property_name         0
# property_type         0
# society               1
# price                20
# price_per_sqft       20
# area                 20
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom        0
# address              11
# floorNum             21
# facing             1177
# agePossession         1
# nearbyLocations     207
# description           0
# furnishDetails     1032
# features            709
# rating              450
# dtype: int64

# %%
df['property_name'].value_counts()
# Out:
# property_name
# 2 BHK Flat in Sohna                                                                      125
# 3 BHK Flat in Sector 102 Gurgaon                                                          76
# 3 BHK Flat in Sector 65 Gurgaon                                                           57
# 3 BHK Flat in Sector 92 Gurgaon                                                           53
# 3 BHK Flat in Sector 69 Gurgaon                                                           51
# 2 BHK Flat in Sector 85 Gurgaon                                                           49
# 3 BHK Flat in Sector 83 Gurgaon                                                           47
# 3 BHK Flat in Sector 81 Gurgaon                                                           45
# 3 BHK Flat in Sector 79 Gurgaon                                                           44
# 3 BHK Flat in Sector 109 Gurgaon                                                          44
# ...

# %%
df[~df['property_name'].str.contains('Sector')]['property_name']
# Out:
# 0                               3 BHK Flat in DLF Phase 3
# 7                                4 BHK Flat in Chakkarpur
# 10                              2 BHK Flat in Ashok Vihar
# 16                8 Bedroom House for sale in Palam Vihar
# 17               7 Bedroom House for sale in Shakti Nagar
# 21            7 Bedroom House for sale in Mianwali Colony
# 24              4 Bedroom House for sale in Shivaji Nagar
# 27                                    3 BHK Flat in Sohna
# 31            5 Bedroom House for sale in Dayanand Colony
# 37                                    1 BHK Flat in Sohna
# 40      5 Bedroom House for sale in Jacobpura Near Sad...
# 45       2 Bedroom House for sale in Laxman Vihar Phase 2
# 46            4 Bedroom House for sale in Nirvana Country
# 64              3 Bedroom House for sale in Surat Nagar 1
# 65                                    2 BHK Flat in Sohna
# 69        3 Bedroom House for sale in Sushant Lok Phase 3
# ...

# %%
df.insert(loc=3, column = 'sector', value = df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon', '').str.strip().str.lower())

# %%
df.head()
# Out:
#                                     property_name property_type  \
# 0                       3 BHK Flat in DLF Phase 3          flat
# 1  5 Bedroom House for sale in Sector 37B Gurgaon         house
# 2                2 BHK Flat in Sector 70A Gurgaon          flat
# 3                 2 BHK Flat in Sector 77 Gurgaon          flat
# 4                 1 BHK Flat in Sector 95 Gurgaon          flat
#
#                   society       sector  price  price_per_sqft    area  \
# 0         ambience lagoon  dlf phase 3   4.25         13281.0  3200.0
# 1             independent   sector 37b   0.95          9500.0  1000.0
# 2  capital residences 360   sector 70a   1.18          8137.0  1450.0
# 3      umang winter hills    sector 77   0.71          5305.0  1338.0
# 4              rof ananda    sector 95   0.20          5463.0   366.0
#
#                                         areaWithType  bedRoom  bathroom  ...  \
# 0  Super Built up area 3200(297.29 sq.m.)Carpet a...        3         4  ...
# ...

# %%
df[~df['sector'].str.contains('sector')]['sector'].value_counts()
# Out:
# sector
# sohna                                                        163
# nirvana country                                               53
# palam vihar                                                   50
# dlf phase 2                                                   43
# dlf phase 1                                                   43
# sushant lok phase 1                                           31
# laxman vihar                                                  27
# dlf phase 4                                                   26
# dlf phase 3                                                   22
# sushant lok phase 3                                           16
# dlf phase 5                                                   14
# gwal pahari                                                   14
# rajendra park                                                 14
# laxman vihar phase 2                                          13
# ...

# %%
area_sector_map = {
    'nirvana country' : 'sector 50',
    'palman vihar': 'sector 2',
    'dlf phase 2': 'sector 25',
    'dlf phase 1' : 'sector 26',
    'sushant lok phase 1': 'sector 43',
    'laxman vihar' : 'sector 4',
    'dlf phase 4': 'sector 28',
    'dlf phase 3': 'sector 24',
    'sushant lok phase 3': 'sector 57',
    'dlf phase 5': 'sector 43',
    'gawal pahar' : 'sector 54',
    'rajendra park': 'sector 105',
    'laxman vihar phase 2': 'sector 3',
    'sohna road': 'sohna',
    'uppals southend': 'sector 49',
    'ashok vihar': 'sector 5',
    'south city 1': 'sector 41',
    'dwarka expressway' : 'dwarka',
    'palam vihar': 'sector 2',
    'malibu town': 'sector 47',
    'mehrauli road': 'sector 14',
    'new colony': 'sector 7',
    'mianwali colony': 'sector 12',
    'surat nagar 1': 'sector 104',
    'rajiv nagar': 'sector 13',
    'jacobpura': 'sector 12',
    'jyoti park': 'sector 7',
    'chakkarpur': 'sector 28',
    'ansal plaza' : 'sector 23',
    'subhash nagar': 'sector 12',
    'saraswati vihar' : 'sector 28',
    'sushant lok phase 2': 'sector 55',
    'arjun nagar': 'sector 8',
    'new palam vihar': 'sector 110',
    'greenwood city': 'sector 45',
    'manesar': 'manesar',
    'dayanand colony': 'sector 6',
    'shivaji nagar': 'sector 11',
    'vishnu garden': 'sector 105',
    'krishna colony': 'sector 7',
    'suncity': 'sector 54',
    'surya vihar': 'sector 21',
    'dharam colony': 'sector 12',
    'imt manesar': 'manesar',
    'ravi nagar': 'sector 9',
    'adarsh nagar': 'sector 12',
    'shivpuri': 'sector 7',
    'bhim nagar': 'sector 6',
    'bhondsi': 'sector 11',
    'baldev nagar': 'sector 7',
    'devilal colony': 'sector 9',
    'garhi harsaru': 'sector 17',
    'valley view estate': 'gawal pahari',
    'madanpuri': 'sector 7',
    'patel nagar': 'sector 15',
    'laxmi garden': 'sector 11',
    'shakti nagar': 'sector 11',
    'maruti kunj': 'sector 12',
    'mg road': 'sector 28',
    'gandhi nagar': 'sector 11',
    'prem nagar': 'sector 13',
    'mehrauli  road' : 'sector 14'
}

# %%
def sector_name (name):
  for key in area_sector_map:
    if key in name.strip():
      return area_sector_map[key]
  return name

# %%
sector_name('dlf phase 2')
# Out:
# 'sector 25'

# %%
df['sector'] = df['sector'].apply(sector_name)

# %%
df['sector']
# Out:
# 0                                               sector 24
# 1                                              sector 37b
# 2                                              sector 70a
# 3                                               sector 77
# 4                                               sector 95
# 5                                               sector 90
# 6                                               sector 68
# 7                                               sector 28
# 8                                               sector 95
# 9                                               sector 67
# 10                                               sector 5
# 11                                              sector 79
# 12                                             sector 113
# 13                                              sector 86
# 14                                              sector 28
# 15                                              sector 92
# ...

# %%
a = df['sector'].value_counts()[df['sector'].value_counts() >= 3]

# %%
df = df[df['sector'].isin(a.index)]

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna              175
# sector 102         113
# sector 85          110
# sector 92          104
# sector 69           94
# sector 81           90
# sector 90           90
# sector 65           90
# sector 109          88
# sector 79           80
# sector 104          73
# sector 2            73
# sector 83           69
# sector 37d          68
# sector 86           67
# sector 43           67
# sector 50           66
# sector 107          60
# sector 108          59
# sector 95           57
# sector 56           57
# sector 48           56
# sector 89           56
# sector 70a          54
# sector 37c          53
# sector 70           53
# sector-33 sohna     51
# sector 84           51
# sector 4            50
# sector 26           50
# sector 67           48
# sector 49           48
# sector 66           46
# sector 28           45
# sector 103          45
# sector 25           43
# sector 113          43
# sector 61           42
# sector 82           42
# ...

# %%
import re
sector = df['sector'].apply(lambda x:re.sub(r'(\d)\s?[a-zA-Z]\b', r'\1', x) if 'sector' in x else x)

# %%
sector.value_counts()
# Out:
# sector
# sohna              175
# sector 37          121
# sector 102         113
# sector 85          110
# sector 70          107
# sector 92          104
# sector 69           94
# sector 90           90
# sector 65           90
# sector 81           90
# sector 109          88
# sector 79           80
# sector 104          73
# sector 2            73
# sector 67           70
# sector 83           69
# sector 86           67
# sector 43           67
# sector 50           66
# sector 95           66
# sector 89           64
# sector 82           62
# sector 107          60
# sector 108          59
# sector 56           57
# sector 48           56
# sector 84           51
# sector-33 sohna     51
# sector 4            50
# sector 26           50
# sector 99           48
# sector 49           48
# sector 66           46
# sector 103          45
# sector 28           45
# sector 113          43
# sector 25           43
# sector 61           42
# sector 7            41
# ...

# %%
sector = sector.str.replace('gawal pahari', 'gwal pahari')
sector = sector.str.replace('sector-33 sohna', 'sector 33')
sector = sector.str.replace('sector 36 sohna', 'sector 36')

# %%
sector.value_counts()
# Out:
# sector
# sohna          175
# sector 37      121
# sector 102     113
# sector 85      110
# sector 70      107
# sector 92      104
# sector 69       94
# sector 90       90
# sector 81       90
# sector 65       90
# sector 109      88
# sector 79       80
# sector 33       74
# sector 104      73
# sector 2        73
# sector 67       70
# sector 83       69
# sector 43       67
# sector 86       67
# sector 50       66
# sector 95       66
# sector 89       64
# sector 82       62
# sector 107      60
# sector 108      59
# sector 56       57
# sector 48       56
# sector 84       51
# sector 4        50
# sector 26       50
# sector 49       48
# sector 99       48
# sector 66       46
# sector 28       45
# sector 103      45
# sector 113      43
# sector 25       43
# sector 61       42
# sector 7        41
# sector 12       38
# sector 106      38
# sector 5        35
# manesar         34
# sector 63       33
# sector 54       31
# sector 68       30
# sector 72       29
# ...

# %%
df[sector == 'new']
# Out:
#                   property_name property_type                       society  \
# 2183  4 BHK Flat in New Gurgaon          flat                    sare homes
# 2567  2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
# 2752  4 BHK Flat in New Gurgaon          flat                        dlf 76
# 2795  2 BHK Flat in New Gurgaon          flat                   green court
#
#      sector  price  price_per_sqft    area  \
# 2183    new   0.85          4786.0  1776.0
# 2567    new   0.67          5583.0  1200.0
# 2752    new   4.00         11428.0  3500.0
# 2795    new   0.38          5507.0   690.0
#
#                                 areaWithType  bedRoom  bathroom  ...  \
# 2183     Super Built up area 1776(165 sq.m.)        4         4  ...
# 2567  Super Built up area 1200(111.48 sq.m.)        2         2  ...
# 2752        Carpet area: 3500 (325.16 sq.m.)        4         4  ...
# 2795           Carpet area: 690 (64.1 sq.m.)        2         2  ...
#
# ...

# %%
df['sector'] = sector

# %%
df[df['sector'] == 'new']
# Out:
#                   property_name property_type                       society  \
# 2183  4 BHK Flat in New Gurgaon          flat                    sare homes
# 2567  2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
# 2752  4 BHK Flat in New Gurgaon          flat                        dlf 76
# 2795  2 BHK Flat in New Gurgaon          flat                   green court
#
#      sector  price  price_per_sqft    area  \
# 2183    new   0.85          4786.0  1776.0
# 2567    new   0.67          5583.0  1200.0
# 2752    new   4.00         11428.0  3500.0
# 2795    new   0.38          5507.0   690.0
#
#                                 areaWithType  bedRoom  bathroom  ...  \
# 2183     Super Built up area 1776(165 sq.m.)        4         4  ...
# 2567  Super Built up area 1200(111.48 sq.m.)        2         2  ...
# 2752        Carpet area: 3500 (325.16 sq.m.)        4         4  ...
# 2795           Carpet area: 690 (64.1 sq.m.)        2         2  ...
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.loc[2567,'sector'] = 'sector 37'
df.loc[2183,'sector'] = 'sector 92'
df.loc[2795,'sector'] = 'sector 90'
df.loc[2752,'sector'] = 'sector 76'

# %%
df.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(122)

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna          175
# sector 37      122
# sector 102     113
# sector 85      110
# sector 70      107
# sector 92      105
# sector 69       94
# sector 90       91
# sector 65       90
# sector 81       90
# sector 109      88
# sector 79       80
# sector 33       74
# sector 2        73
# sector 104      73
# sector 67       70
# sector 83       69
# sector 86       67
# sector 43       67
# sector 95       66
# sector 50       66
# sector 89       64
# sector 82       62
# sector 107      60
# sector 108      59
# sector 56       57
# sector 48       56
# sector 84       51
# sector 26       50
# sector 4        50
# sector 99       48
# sector 49       48
# sector 66       46
# sector 28       45
# sector 103      45
# sector 113      43
# sector 25       43
# sector 61       42
# sector 7        41
# sector 106      38
# sector 12       38
# sector 5        35
# manesar         34
# sector 63       33
# sector 54       31
# sector 68       30
# sector 77       29
# ...

# %%
df.to_csv('gurgaon_properties_cleaned_v1.csv',index=False)
